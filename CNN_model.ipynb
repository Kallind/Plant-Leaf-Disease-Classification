# %% [markdown]
# # Main Library

# %%
# Reading Data
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# Data Preprocessing 
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# Building CNN Model & Pretraining Model
import tensorflow as tf
import tensorflow.keras as k
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, AveragePooling2D, Flatten, Dropout

# Downlaod Model
import pickle

# %% [markdown]
# # Reading Data(Image)

# %%
path_folder = "C:/Users/Jay Ajmera/Desktop/Nasheee/hach_summit/train"
class_name = os.listdir(path_folder)
class_name.sort()
class_name = class_name[:4] + class_name[20:23]
print(class_name)
image_data = []
label_data = []
count = 0
for folder in class_name:
    images = os.listdir(path_folder + "/" + folder)
    print("Loading Folder -- {} " .format(folder), "The Count of Classes ==> ",count)
    for img in images:
        image = cv2.imread(path_folder + "/" + folder + "/" + img)
        image = cv2.resize(image, (100, 100))
        
        image_data.append(image)
        label_data.append(count)
    count += 1
print("---- Done ----------- ")
# Out:
# ['Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy']
# Loading Folder -- Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot  The Count of Classes ==>  0
# Loading Folder -- Corn_(maize)___Common_rust_  The Count of Classes ==>  1
# Loading Folder -- Corn_(maize)___Northern_Leaf_Blight  The Count of Classes ==>  2
# Loading Folder -- Corn_(maize)___healthy  The Count of Classes ==>  3
# ---- Done -----------

# %% [markdown]
# # Preprocessing Data & Visualization

# %%
data = np.array(image_data)
data = data.astype("float32")
data = data/255.0

label = np.array(label_data)

# %%
print(data.shape)
# Out:
# (7316, 100, 100, 3)

# %% [markdown]
# ## Transform Label To One Hot Encoder

# %%
label_num = to_categorical(label, len(class_name))
label_num[100]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %% [markdown]
# # Shuffle Data

# %%
x_img, y_img = shuffle(data, label_num)
x_train, x_test, y_train, y_test = train_test_split(x_img, y_img, train_size=0.8)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5852, 100, 100, 3), (5852, 4), (1464, 100, 100, 3), (1464, 4))

# %% [markdown]
# # Visualization Some Data

# %%
plt.figure(figsize=(10, 10))
for i in range(0, 25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i])
    plt.title(class_name[np.argmax(y_train[i])])

# %% [markdown]
# # Building CNN Model

# %%
model = k.models.Sequential()

model.add(k.layers.Conv2D(16, (5, 5), activation="relu", input_shape=(100, 100, 3), padding="same"))
model.add(k.layers.AveragePooling2D((2, 2)))

model.add(k.layers.Conv2D(32, (4, 4), activation="relu",  padding="same"))
# model.add(k.layers.BatchNormalization())
model.add(k.layers.AveragePooling2D((2, 2)))


model.add(k.layers.Conv2D(64, (3, 3), activation="relu", padding="same"))
model.add(k.layers.AveragePooling2D((2, 2)))

model.add(k.layers.Conv2D(128, (2, 2), activation="relu", padding="same"))
model.add(k.layers.MaxPool2D((2, 2)))

model.add(k.layers.Flatten())

model.add(k.layers.Dense(256, activation="relu"))
# model.add(k.layers.BatchNormalization())
model.add(k.layers.Dropout(0.5))

model.add(k.layers.Dense(32, activation="relu"))
model.add(k.layers.Dropout(0.2))

model.add(k.layers.Dense(4, activation="softmax"))

model.compile(optimizer="adam", loss=k.losses.CategoricalCrossentropy(), metrics=["accuracy"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 16)      1216
#
#  average_pooling2d (Average  (None, 50, 50, 16)        0
#  Pooling2D)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        8224
#
#  average_pooling2d_1 (Avera  (None, 25, 25, 32)        0
#  gePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        18496
#
#  average_pooling2d_2 (Avera  (None, 12, 12, 64)        0
#  gePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       32896
#
#  max_pooling2d (MaxPooling2  (None, 6, 6, 128)         0
#  D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 32)                8224
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 1249092 (4.76 MB)
# Trainable params: 1249092 (4.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), validation_split=0.4)
# Out:
# Epoch 1/50
# 183/183 [==============================] - 43s 227ms/step - loss: 0.6064 - accuracy: 0.7276 - val_loss: 0.3017 - val_accuracy: 0.8852
# Epoch 2/50
# 183/183 [==============================] - 43s 234ms/step - loss: 0.2857 - accuracy: 0.8836 - val_loss: 0.1790 - val_accuracy: 0.9337
# Epoch 3/50
# 183/183 [==============================] - 47s 258ms/step - loss: 0.1802 - accuracy: 0.9287 - val_loss: 0.1801 - val_accuracy: 0.9378
# Epoch 4/50
# 183/183 [==============================] - 43s 237ms/step - loss: 0.1767 - accuracy: 0.9385 - val_loss: 0.1504 - val_accuracy: 0.9378
# Epoch 5/50
# 183/183 [==============================] - 39s 216ms/step - loss: 0.1312 - accuracy: 0.9508 - val_loss: 0.1234 - val_accuracy: 0.9611
# Epoch 6/50
# 183/183 [==============================] - 39s 211ms/step - loss: 0.1264 - accuracy: 0.9581 - val_loss: 0.1262 - val_accuracy: 0.9549
# Epoch 7/50
# 183/183 [==============================] - 40s 217ms/step - loss: 0.1330 - accuracy: 0.9518 - val_loss: 0.1114 - val_accuracy: 0.9577
# Epoch 8/50
# 183/183 [==============================] - 43s 237ms/step - loss: 0.1093 - accuracy: 0.9610 - val_loss: 0.1240 - val_accuracy: 0.9570
# Epoch 9/50
# 183/183 [==============================] - 46s 254ms/step - loss: 0.1023 - accuracy: 0.9651 - val_loss: 0.0994 - val_accuracy: 0.9713
# Epoch 10/50
# 183/183 [==============================] - 49s 266ms/step - loss: 0.0928 - accuracy: 0.9651 - val_loss: 0.0926 - val_accuracy: 0.9713
# Epoch 11/50
# 183/183 [==============================] - 47s 254ms/step - loss: 0.1074 - accuracy: 0.9609 - val_loss: 0.1027 - val_accuracy: 0.9686
# Epoch 12/50
# 183/183 [==============================] - 49s 266ms/step - loss: 0.0988 - accuracy: 0.9643 - val_loss: 0.0940 - val_accuracy: 0.9727
# Epoch 13/50
# 183/183 [==============================] - 46s 252ms/step - loss: 0.0946 - accuracy: 0.9643 - val_loss: 0.0951 - val_accuracy: 0.9734
# Epoch 14/50
# 183/183 [==============================] - 46s 250ms/step - loss: 0.0817 - accuracy: 0.9675 - val_loss: 0.1024 - val_accuracy: 0.9679
# Epoch 15/50
# 183/183 [==============================] - 47s 257ms/step - loss: 0.1164 - accuracy: 0.9580 - val_loss: 0.1175 - val_accuracy: 0.9693
# Epoch 16/50
# 183/183 [==============================] - 46s 249ms/step - loss: 0.0945 - accuracy: 0.9657 - val_loss: 0.1003 - val_accuracy: 0.9679
# Epoch 17/50
# 183/183 [==============================] - 45s 248ms/step - loss: 0.0834 - accuracy: 0.9687 - val_loss: 0.0763 - val_accuracy: 0.9747
# Epoch 18/50
# 183/183 [==============================] - 42s 231ms/step - loss: 0.1009 - accuracy: 0.9612 - val_loss: 0.1151 - val_accuracy: 0.9577
# Epoch 19/50
# 183/183 [==============================] - 43s 234ms/step - loss: 0.0936 - accuracy: 0.9645 - val_loss: 0.0927 - val_accuracy: 0.9713
# Epoch 20/50
# 183/183 [==============================] - 46s 249ms/step - loss: 0.0826 - accuracy: 0.9704 - val_loss: 0.0875 - val_accuracy: 0.9747
# Epoch 21/50
# 183/183 [==============================] - 40s 219ms/step - loss: 0.0657 - accuracy: 0.9762 - val_loss: 0.1001 - val_accuracy: 0.9597
# Epoch 22/50
# 183/183 [==============================] - 42s 232ms/step - loss: 0.0572 - accuracy: 0.9786 - val_loss: 0.1195 - val_accuracy: 0.9686
# Epoch 23/50
# 183/183 [==============================] - 46s 250ms/step - loss: 0.0649 - accuracy: 0.9771 - val_loss: 0.1086 - val_accuracy: 0.9693
# Epoch 24/50
# 183/183 [==============================] - 45s 246ms/step - loss: 0.0702 - accuracy: 0.9744 - val_loss: 0.1207 - val_accuracy: 0.9577
# Epoch 25/50
# 183/183 [==============================] - 44s 241ms/step - loss: 0.0459 - accuracy: 0.9833 - val_loss: 0.1343 - val_accuracy: 0.9624
# Epoch 26/50
# 183/183 [==============================] - 46s 254ms/step - loss: 0.0524 - accuracy: 0.9807 - val_loss: 0.1126 - val_accuracy: 0.9727
# Epoch 27/50
# 183/183 [==============================] - 44s 243ms/step - loss: 0.0533 - accuracy: 0.9815 - val_loss: 0.1839 - val_accuracy: 0.9706
# Epoch 28/50
# 183/183 [==============================] - 44s 243ms/step - loss: 0.0584 - accuracy: 0.9807 - val_loss: 0.0976 - val_accuracy: 0.9754
# Epoch 29/50
# 183/183 [==============================] - 46s 250ms/step - loss: 0.0553 - accuracy: 0.9802 - val_loss: 0.1101 - val_accuracy: 0.9672
# Epoch 30/50
# 183/183 [==============================] - 42s 228ms/step - loss: 0.0453 - accuracy: 0.9843 - val_loss: 1.7667 - val_accuracy: 0.6872
# Epoch 31/50
# 183/183 [==============================] - 42s 232ms/step - loss: 0.0899 - accuracy: 0.9727 - val_loss: 0.1095 - val_accuracy: 0.9734
# Epoch 32/50
# 183/183 [==============================] - 46s 251ms/step - loss: 0.0420 - accuracy: 0.9856 - val_loss: 0.1681 - val_accuracy: 0.9679
# Epoch 33/50
# 183/183 [==============================] - 43s 233ms/step - loss: 0.0329 - accuracy: 0.9891 - val_loss: 0.1236 - val_accuracy: 0.9781
# Epoch 34/50
# 183/183 [==============================] - 42s 227ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 0.1598 - val_accuracy: 0.9604
# Epoch 35/50
# 183/183 [==============================] - 35s 192ms/step - loss: 0.0292 - accuracy: 0.9894 - val_loss: 0.2917 - val_accuracy: 0.9522
# Epoch 36/50
# 183/183 [==============================] - 35s 190ms/step - loss: 0.0340 - accuracy: 0.9867 - val_loss: 0.1201 - val_accuracy: 0.9754
# Epoch 37/50
# 183/183 [==============================] - 41s 223ms/step - loss: 0.0316 - accuracy: 0.9906 - val_loss: 0.1433 - val_accuracy: 0.9658
# Epoch 38/50
# 183/183 [==============================] - 44s 239ms/step - loss: 0.0489 - accuracy: 0.9831 - val_loss: 0.1373 - val_accuracy: 0.9727
# Epoch 39/50
# 183/183 [==============================] - 45s 247ms/step - loss: 0.0238 - accuracy: 0.9923 - val_loss: 0.1308 - val_accuracy: 0.9747
# Epoch 40/50
# 183/183 [==============================] - 48s 265ms/step - loss: 0.0351 - accuracy: 0.9872 - val_loss: 0.1539 - val_accuracy: 0.9727
# Epoch 41/50
# 183/183 [==============================] - 52s 283ms/step - loss: 0.0190 - accuracy: 0.9932 - val_loss: 0.1799 - val_accuracy: 0.9672
# Epoch 42/50
# 183/183 [==============================] - 48s 260ms/step - loss: 0.0279 - accuracy: 0.9903 - val_loss: 0.1596 - val_accuracy: 0.9734
# Epoch 43/50
# 183/183 [==============================] - 47s 260ms/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.1226 - val_accuracy: 0.9720
# Epoch 44/50
# 183/183 [==============================] - 46s 254ms/step - loss: 0.0264 - accuracy: 0.9911 - val_loss: 0.1882 - val_accuracy: 0.9563
# Epoch 45/50
# 183/183 [==============================] - 46s 251ms/step - loss: 0.0297 - accuracy: 0.9886 - val_loss: 0.1468 - val_accuracy: 0.9672
# Epoch 46/50
# 183/183 [==============================] - 38s 206ms/step - loss: 0.0244 - accuracy: 0.9927 - val_loss: 0.1331 - val_accuracy: 0.9679
# Epoch 47/50
# 183/183 [==============================] - 36s 195ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.1235 - val_accuracy: 0.9740
# Epoch 48/50
# 183/183 [==============================] - 36s 197ms/step - loss: 0.0409 - accuracy: 0.9891 - val_loss: 0.0965 - val_accuracy: 0.9706
# Epoch 49/50
# 183/183 [==============================] - 37s 205ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 0.1470 - val_accuracy: 0.9679
# Epoch 50/50
# 183/183 [==============================] - 43s 234ms/step - loss: 0.0179 - accuracy: 0.9935 - val_loss: 0.1267 - val_accuracy: 0.9713

# %%
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="Val_Loss")

plt.xlabel("Epochs")
plt.ylabel("Loss")

plt.title("Loss Vs Epochs")

plt.legend()
plt.grid()

# %%
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.title("Accuracy Vs Epochs")

plt.legend()
plt.grid()

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print(f"The Accuracy Testing Data is ==> {accuracy} %")
print(f"The loss Testing Data is ==> {loss}")
# Out:
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1267 - accuracy: 0.9713
# The Accuracy Testing Data is ==> 0.9713114500045776 %
# The loss Testing Data is ==> 0.12670552730560303

# %% [markdown]
# # System Prediction

# %%
path_img1 = input()
image = cv2.imread(path_img1)
image = cv2.resize(image, (100, 100))
# image = image/255.0
# print(image1.shape)
new_image = np.reshape(image, [1, 100, 100, 3])

# ================== Show Prediction =================================

prediction = model.predict(new_image)[0]
# print(prediction1)

new_prediction = class_name[np.argmax(prediction)]
print("The Prediction is ==> ",prediction)

print("Type Of Planet ==>", new_prediction[:new_prediction.index("__")])
print("Type Disease Of Planet ==>", new_prediction[new_prediction.index("__")+3:])

# ================== Show image And Label Prediction =================================

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title(new_prediction)
plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step
# The Prediction is ==>  [0. 0. 1. 0.]
# Type Of Planet ==> Corn_(maize)
# Type Disease Of Planet ==> Northern_Leaf_Blight

# %% [markdown]
# # Show Prediction

# %%
path_test = r"D:\Prototype-Green-Hackathon\testing"
image_testing = []
label_testing = []
for img in os.listdir(path_test):
    image = path_test + "\\" + img
    image = cv2.imread(image)
    new_image = cv2.resize(image, (224, 224))
    image_testing.append(new_image)
    label_testing.append(img[:-5])

image_testing = np.array(image_testing)
label_testing = np.array(label_testing)

plt.figure(figsize=(10, 10))
for i in range(12):
    plt.subplot(6, 2, i + 1)
    plt.xticks([])
    plt.yticks([])
    new_image = np.resize(image_testing[i], [1, 224, 224, 3])
    prediction = model.predict(new_image)
    prediction = prediction[0]
    print(prediction)
    plt.imshow(image_testing[i])
    plt.title(f"The Real Prediction is {label_testing[i]} \n The model Prediction is {class_name[np.argmax(prediction)]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 image_testing = []
#       3 label_testing = []
# ----> 4 for img in os.listdir(path_test):
#       5     image = path_test + "\\" + img
#       6     image = cv2.imread(image)
#
# NameError: name 'os' is not defined

# %% [markdown]
# # Download CNN Model

# %%
with open('model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# %%
model.save('pickle Hackathon_model.hin')
# Out:
# INFO:tensorflow:Assets written to: pickle Hackathon_model.hin\assets
# INFO:tensorflow:Assets written to: pickle Hackathon_model.hin\assets
